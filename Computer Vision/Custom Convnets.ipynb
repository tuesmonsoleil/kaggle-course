# %% [markdown]
# **This notebook is an exercise in the [Computer Vision](https://www.kaggle.com/learn/computer-vision) course.  You can reference the tutorial at [this link](https://www.kaggle.com/ryanholbrook/custom-convnets).**
#
# ---

# %% [markdown]
# # Introduction #
#
# In these exercises, you'll build a custom convnet with performance competitive to the VGG16 model from Lesson 1.
#
# Get started by running the code cell below.

# %%
# Setup feedback system
from learntools.core import binder
binder.bind(globals())
from learntools.computer_vision.ex5 import *

# Imports
import os, warnings
import matplotlib.pyplot as plt
from matplotlib import gridspec

import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory

# Reproducability
def set_seed(seed=31415):
    np.random.seed(seed)
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    os.environ['TF_DETERMINISTIC_OPS'] = '1'
set_seed()

# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('image', cmap='magma')
warnings.filterwarnings("ignore") # to clean up output cells


# Load training and validation sets
ds_train_ = image_dataset_from_directory(
    '../input/car-or-truck/train',
    labels='inferred',
    label_mode='binary',
    image_size=[128, 128],
    interpolation='nearest',
    batch_size=64,
    shuffle=True,
)
ds_valid_ = image_dataset_from_directory(
    '../input/car-or-truck/valid',
    labels='inferred',
    label_mode='binary',
    image_size=[128, 128],
    interpolation='nearest',
    batch_size=64,
    shuffle=False,
)

# Data Pipeline
def convert_to_float(image, label):
    image = tf.image.convert_image_dtype(image, dtype=tf.float32)
    return image, label

AUTOTUNE = tf.data.experimental.AUTOTUNE
ds_train = (
    ds_train_
    .map(convert_to_float)
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)
ds_valid = (
    ds_valid_
    .map(convert_to_float)
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)
# Out:
# 2024-05-03 07:25:07.106945: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-03 07:25:07.107030: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-03 07:25:07.234462: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Found 5117 files belonging to 2 classes.
# Found 5051 files belonging to 2 classes.

# %% [markdown]
# # Design a Convnet #
#
# Let's design a convolutional network with a block architecture like we saw in the tutorial. The model from the example had three blocks, each with a single convolutional layer. Its performance on the "Car or Truck" problem was okay, but far from what the pretrained VGG16 could achieve. It might be that our simple network lacks the ability to extract sufficiently complex features. We could try improving the model either by adding more blocks or by adding convolutions to the blocks we have.
#
# Let's go with the second approach. We'll keep the three block structure, but increase the number of `Conv2D` layer in the second block to two, and in the third block to three.
#
# <figure>
# <!-- <img src="./images/2-convmodel-2.png" width="250" alt="Diagram of a convolutional model."> -->
# <img src="https://storage.googleapis.com/kaggle-media/learn/images/Vko6nCK.png" width="250" alt="Diagram of a convolutional model.">
# </figure>
#
# # 1) Define Model #
#
# Given the diagram above, complete the model by defining the layers of the third block.

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    # Block One
    layers.Conv2D(filters=32, kernel_size=3, activation='relu', padding='same',
                  input_shape=[128, 128, 3]),
    layers.MaxPool2D(),

    # Block Two
    layers.Conv2D(filters=64, kernel_size=3, activation='relu', padding='same'),
    layers.MaxPool2D(),

    # Block Three
    # YOUR CODE HERE
    layers.Conv2D(filters=128, kernel_size=3, activation="relu", padding='same'),
    layers.Conv2D(filters=128, kernel_size=3, activation="relu", padding='same'),
    layers.MaxPool2D(),

    # Head
    layers.Flatten(),
    layers.Dense(6, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(1, activation='sigmoid'),
])

# Check your answer
q_1.check()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
q_1.hint()
q_1.solution()
# Out:
# Hint: You should add two `Conv2D` layers and then a `MaxPool2D` layer. They will be just the same as the other layers in the model, except for some of the parameter values.
# Solution:
# ```python
#
# from tensorflow import keras
# from tensorflow.keras import layers
#
# model = keras.Sequential([
#     # Block One
#     layers.Conv2D(filters=32, kernel_size=3, activation='relu', padding='same',
#                   input_shape=[128, 128, 3]),
#     layers.MaxPool2D(),
#
#     # Block Two
#     layers.Conv2D(filters=64, kernel_size=3, activation='relu', padding='same'),
#     layers.MaxPool2D(),
#
#     # Block Three
#     layers.Conv2D(filters=128, kernel_size=3, activation='relu', padding='same'),
#     layers.Conv2D(filters=128, kernel_size=3, activation='relu', padding='same'),
#     layers.MaxPool2D(),
#
#     # Head
#     layers.Flatten(),
#     layers.Dense(6, activation='relu'),
#     layers.Dropout(0.2),
#     layers.Dense(1, activation='sigmoid'),
# ])
#
# ```

# %% [markdown]
# # 2) Compile #
#
# To prepare for training, compile the model with an appropriate loss and accuracy metric for the "Car or Truck" dataset.

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(epsilon=0.01),
    # YOUR CODE HERE: Add loss and metric
    loss='binary_crossentropy',
    metrics=['binary_accuracy']
)

# Check your answer
q_2.check()
# Out:
# Correct

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(epsilon=0.01),
    loss='binary_crossentropy',
    metrics=['binary_accuracy'],
)
q_2.assert_check_passed()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
q_2.hint()
q_2.solution()
# Out:
# Hint: This is a *binary* classification problem.
# Solution:
# ```python
#
# model.compile(
#     optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
#     loss='binary_crossentropy',
#     metrics=['binary_accuracy'],
# )
#
# ```

# %% [markdown]
# Finally, let's test the performance of this new model. First run this cell to fit the model to the training set.

# %%
history = model.fit(
    ds_train,
    validation_data=ds_valid,
    epochs=50,
)
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1714724507.955539     102 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 80/80 [==============================] - 22s 206ms/step - loss: 0.6805 - binary_accuracy: 0.5787 - val_loss: 0.6690 - val_binary_accuracy: 0.5785
# Epoch 2/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.6657 - binary_accuracy: 0.5787 - val_loss: 0.6565 - val_binary_accuracy: 0.5785
# Epoch 3/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.6579 - binary_accuracy: 0.5787 - val_loss: 0.6495 - val_binary_accuracy: 0.5785
# Epoch 4/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.6545 - binary_accuracy: 0.5787 - val_loss: 0.6456 - val_binary_accuracy: 0.5785
# Epoch 5/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.6474 - binary_accuracy: 0.6166 - val_loss: 0.6370 - val_binary_accuracy: 0.6296
# Epoch 6/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.6379 - binary_accuracy: 0.6308 - val_loss: 0.6306 - val_binary_accuracy: 0.6244
# Epoch 7/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.6283 - binary_accuracy: 0.6484 - val_loss: 0.6194 - val_binary_accuracy: 0.6518
# Epoch 8/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.6222 - binary_accuracy: 0.6607 - val_loss: 0.6133 - val_binary_accuracy: 0.6656
# Epoch 9/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.6137 - binary_accuracy: 0.6713 - val_loss: 0.6040 - val_binary_accuracy: 0.6816
# Epoch 10/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.6067 - binary_accuracy: 0.6826 - val_loss: 0.5983 - val_binary_accuracy: 0.6953
# Epoch 11/50
# 80/80 [==============================] - 3s 39ms/step - loss: 0.5981 - binary_accuracy: 0.6996 - val_loss: 0.5899 - val_binary_accuracy: 0.7070
# Epoch 12/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.5880 - binary_accuracy: 0.7098 - val_loss: 0.5797 - val_binary_accuracy: 0.7014
# Epoch 13/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.5732 - binary_accuracy: 0.7297 - val_loss: 0.5689 - val_binary_accuracy: 0.7286
# Epoch 14/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.5574 - binary_accuracy: 0.7440 - val_loss: 0.5632 - val_binary_accuracy: 0.7412
# Epoch 15/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.5456 - binary_accuracy: 0.7471 - val_loss: 0.5510 - val_binary_accuracy: 0.7472
# Epoch 16/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.5274 - binary_accuracy: 0.7620 - val_loss: 0.5478 - val_binary_accuracy: 0.7484
# Epoch 17/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.5047 - binary_accuracy: 0.7835 - val_loss: 0.5429 - val_binary_accuracy: 0.7391
# Epoch 18/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.4916 - binary_accuracy: 0.7944 - val_loss: 0.5279 - val_binary_accuracy: 0.7670
# Epoch 19/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.4830 - binary_accuracy: 0.8005 - val_loss: 0.5471 - val_binary_accuracy: 0.7349
# Epoch 20/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.4634 - binary_accuracy: 0.8056 - val_loss: 0.5221 - val_binary_accuracy: 0.7597
# Epoch 21/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.4474 - binary_accuracy: 0.8214 - val_loss: 0.5384 - val_binary_accuracy: 0.7434
# Epoch 22/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.4356 - binary_accuracy: 0.8188 - val_loss: 0.4914 - val_binary_accuracy: 0.7709
# Epoch 23/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.3960 - binary_accuracy: 0.8505 - val_loss: 0.4510 - val_binary_accuracy: 0.7935
# Epoch 24/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.3668 - binary_accuracy: 0.8444 - val_loss: 0.5236 - val_binary_accuracy: 0.7240
# Epoch 25/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.3288 - binary_accuracy: 0.8663 - val_loss: 0.4491 - val_binary_accuracy: 0.7919
# Epoch 26/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.3211 - binary_accuracy: 0.8697 - val_loss: 0.4196 - val_binary_accuracy: 0.8074
# Epoch 27/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.2780 - binary_accuracy: 0.8859 - val_loss: 0.5183 - val_binary_accuracy: 0.7652
# Epoch 28/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.2803 - binary_accuracy: 0.8814 - val_loss: 0.4064 - val_binary_accuracy: 0.8337
# Epoch 29/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.2653 - binary_accuracy: 0.8894 - val_loss: 0.4445 - val_binary_accuracy: 0.8325
# Epoch 30/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.2392 - binary_accuracy: 0.8968 - val_loss: 0.4743 - val_binary_accuracy: 0.8295
# Epoch 31/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.2277 - binary_accuracy: 0.9056 - val_loss: 0.4906 - val_binary_accuracy: 0.8313
# Epoch 32/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.2239 - binary_accuracy: 0.9062 - val_loss: 0.5405 - val_binary_accuracy: 0.8194
# Epoch 33/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.1868 - binary_accuracy: 0.9238 - val_loss: 0.6503 - val_binary_accuracy: 0.8012
# Epoch 34/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.1879 - binary_accuracy: 0.9220 - val_loss: 0.4395 - val_binary_accuracy: 0.8412
# Epoch 35/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.1543 - binary_accuracy: 0.9386 - val_loss: 0.5071 - val_binary_accuracy: 0.8408
# Epoch 36/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.1410 - binary_accuracy: 0.9451 - val_loss: 0.6434 - val_binary_accuracy: 0.8309
# Epoch 37/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.1358 - binary_accuracy: 0.9480 - val_loss: 0.5945 - val_binary_accuracy: 0.8388
# Epoch 38/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.1417 - binary_accuracy: 0.9439 - val_loss: 0.6508 - val_binary_accuracy: 0.8327
# Epoch 39/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.1330 - binary_accuracy: 0.9472 - val_loss: 0.5427 - val_binary_accuracy: 0.8382
# Epoch 40/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.1338 - binary_accuracy: 0.9494 - val_loss: 0.4656 - val_binary_accuracy: 0.8481
# Epoch 41/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.1268 - binary_accuracy: 0.9500 - val_loss: 0.4450 - val_binary_accuracy: 0.8424
# Epoch 42/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.1153 - binary_accuracy: 0.9594 - val_loss: 0.4851 - val_binary_accuracy: 0.8347
# Epoch 43/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.1044 - binary_accuracy: 0.9621 - val_loss: 0.4891 - val_binary_accuracy: 0.8254
# Epoch 44/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.0931 - binary_accuracy: 0.9670 - val_loss: 0.4656 - val_binary_accuracy: 0.8458
# Epoch 45/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.0903 - binary_accuracy: 0.9689 - val_loss: 0.5361 - val_binary_accuracy: 0.8525
# Epoch 46/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.0800 - binary_accuracy: 0.9744 - val_loss: 0.5931 - val_binary_accuracy: 0.8485
# Epoch 47/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.0754 - binary_accuracy: 0.9744 - val_loss: 0.6479 - val_binary_accuracy: 0.8592
# Epoch 48/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.0668 - binary_accuracy: 0.9779 - val_loss: 0.6661 - val_binary_accuracy: 0.8537
# Epoch 49/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.0623 - binary_accuracy: 0.9822 - val_loss: 0.7206 - val_binary_accuracy: 0.8527
# Epoch 50/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.0548 - binary_accuracy: 0.9836 - val_loss: 0.8086 - val_binary_accuracy: 0.8545

# %% [markdown]
# And now run the cell below to plot the loss and metric curves for this training run.

# %%
import pandas as pd
history_frame = pd.DataFrame(history.history)
history_frame.loc[:, ['loss', 'val_loss']].plot()
history_frame.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot();

# %% [markdown]
# # 3) Train the Model #
#
# How would you interpret these training curves? Did this model improve upon the model from the tutorial?

# %%
# View the solution (Run this code cell to receive credit!)
q_3.check()
# Out:
# Correct:
#
#
# The learning curves for the model from the tutorial diverged fairly rapidly. This would indicate that it was prone to overfitting and in need of some regularization. The additional layer in our new model would make it even more prone to overfitting. However, adding some regularization with the `Dropout` layer helped prevent this. These changes improved the validation accuracy of the model by several points.

# %% [markdown]
# # Conclusion #
#
# These exercises showed you how to design a custom convolutional network to solve a specific classification problem. Though most models these days will be built on top of a pretrained base, it certain circumstances a smaller custom convnet might still be preferable -- such as with a smaller or unusual dataset or when computing resources are very limited. As you saw here, for certain problems they can perform just as well as a pretrained model.
#
# # Keep Going #
#
# Continue on to [**Lesson 6**](https://www.kaggle.com/ryanholbrook/data-augmentation), where you'll learn a widely-used technique that can give a boost to your training data: **data augmentation**.

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/computer-vision/discussion) to chat with other learners.*
